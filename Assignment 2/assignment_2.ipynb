# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from load_mnist import load_mnist
from utils import NeuralNetwork
import numpy as np
np.random.seed(0)

# %%
X_train, y_train, X_test, y_test = load_mnist()

# %%
model_architecture = {
        "hidden_layer_1": {"units": 64, "activation_function": "relu"},
        "hidden_layer_2": {"units": 16, "activation_function": "relu"},
    }
neural_network = NeuralNetwork(model_architecture)
neural_network.train_model(
    X_train,
    y_train,
    X_test,
    y_test,
    learning_rate=0.01,
    mini_batch_size=64,
    iterations=100,
)
# Out:
# Network architecture:
#
# hidden_layer_1: {'units': 100, 'activation_function': 'relu'}
# W shape: (100, 784)
# b shape: (100, 1)
#
# output_layer: {'units': 10, 'activation_function': 'softmax'}
# W shape: (10, 100)
# b shape: (10, 1)
#
# Training started...
# Train Cost: 1.7908188531520286
# Train Cost: 1.5298283774676942
# Train Cost: 1.5104863168090275
# Train Cost: 1.5010148744428484
# Train Cost: 1.4950776517768343
# Train Cost: 1.4909187620111162
# Train Cost: 1.4876837999433743
# Train Cost: 1.4851480538003825
# Train Cost: 1.483079827560527
# Train Cost: 1.4814739475721557
# Training completed!
#
# Final Train Accuracy: 98.73333333333333
# Test Accuracy: 97.5

# %%
neural_network.plot_weights()

# %%
neural_network.train_model(
    X_train,
    y_train,
    X_test,
    y_test,
    learning_rate=0.01,
    mini_batch_size=64,
    iterations=100,
)
# Out:
# Network architecture:
#
# hidden_layer_1: {'units': 100, 'activation_function': 'relu'}
# W shape: (100, 784)
# b shape: (100, 1)
#
# output_layer: {'units': 10, 'activation_function': 'softmax'}
# W shape: (10, 10)
# b shape: (10, 1)
#
# Training started...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 neural_network.train_model(
#       2     X_train,
#       3     y_train,
#       4     X_test,
#       5     y_test,
#       6     learning_rate=0.01,
#       7     mini_batch_size=64,
#       8     iterations=100,
#       9 )
#
# File c:\Users\victo\Uni Courses\DL4IA\Assignment 2\utils.py:428, in NeuralNetwork.train_model(self, X_train, y_train, X_test, y_test, learning_rate, mini_batch_size, iterations)
#     426 mini_batches = self.random_mini_batches(X_train, y_train, mini_batch_size)
#     427 for X_mini_batch, y_mini_batch in mini_batches:
# --> 428     self.model_forward(X_mini_batch)
#     429     epoch_cost += np.mean(self.compute_cost(y_mini_batch), axis=0)
#     430     self.model_backward(y_mini_batch)
#
# File c:\Users\victo\Uni Courses\DL4IA\Assignment 2\utils.py:167, in NeuralNetwork.model_forward(self, X)
#     164 for layer in self.model_state:
#     165     # Linear forward
#     166     self.model_state[layer]["linear_input"] = feedforward_input
# --> 167     self.model_state[layer]["linear_output"] = self.linear_forward(
#     168         feedforward_input,
#     169         self.model_state[layer]["W"],
#     170         self.model_state[layer]["b"],
#     171     )
#     173     # Activation forward
#     174     self.model_state[layer]["activation_output"] = self.activation_forward(
#     175         self.model_state[layer]["linear_output"],
#     176         self.model_architecture[layer]["activation_function"],
#     177     )
#
# File c:\Users\victo\Uni Courses\DL4IA\Assignment 2\utils.py:97, in NeuralNetwork.linear_forward(self, X, W, b)
#      86 def linear_forward(self, X: np.ndarray, W: np.ndarray, b: np.ndarray) -> np.ndarray:
#      87     """Performs the linear part of the forward propagation.
#      88
#      89     Args:
#    (...)
#      95         Z (np.ndarray): Linear output
#      96     """
# ---> 97     return np.dot(W, X) + b
#
# ValueError: shapes (10,10) and (100,64) not aligned: 10 (dim 1) != 100 (dim 0)
